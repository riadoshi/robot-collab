# %%
import numpy as np 
import mediapy


data = np.load("/iris/u/riadoshi/teams/robot-collab/sweep_demos/demo_001_fail.npz", allow_pickle=True)

# %%
mediapy.show_video([data['traj'][i]['obs']['ur5_wrist'] for i in range(len(data['traj']))])
